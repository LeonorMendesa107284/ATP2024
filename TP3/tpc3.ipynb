# %%
import random

print(" Jogo dos 21 fosforos")

print(" Regras do jogo:")
print(" Cada jogador (computador ou utilizador), pode tirar 1,2, 3 ou 4 fósforos quando for a sua vez de jogar.")
print(" Os jogadores jogam alternadamente e o jogador que tirar o último fósforo perde!")

print(" Este jogo tem duas modalidades: ")
print(" 1ª modalidade- o jogador joga em primeiro lugar e o computador começa a jogar em segundo lugar.")
print(" 2ª modalidade- o computador começa em primeiro e o jogador joga em segundo lugar.")

mod=int(input(" Que modalidade pretende jogar (1 ou 2)?"))
inicio=21

while mod!= 1 and mod!=2:
    print(" Resposta inválida!")
    mod=int(input(" Que modalidade pretende jogar (1 ou 2)?"))

if mod==1:
    print(" Você é o primeiro a jogar!")
    numfosforos=int(input(" Dos 21 fosforos em jogo só pode tirar 1,2, 3 ou 4 fósforos, digite o número de fosforos que quer tirar:"))
    while numfosforos!=1 and numfosforos!=2 and numfosforos!=3 and numfosforos!=4 :
        print(" Resposta inválida!")
        numfosforos=int(input(" Só pode retirar 1,2,3 ou 4 fosforos dos 21. Quantos quer tirar?"))
    if numfosforos==1 or numfosforos==2 or numfosforos==3 or numfosforos==4  :
        inicio=inicio-numfosforos
        print(f" Removi {numfosforos} e sobram {inicio} fosforos.")
        while inicio>5:
            pc_fosforos=5-numfosforos
            inicio=inicio-pc_fosforos
            print(f" O computador removeu {pc_fosforos} e sobram {inicio} fosforos.")
            numfosforos=int(input(f" Dos {inicio} fosforos em jogo só pode tirar 1,2, 3 ou 4 fósforos, digite o número de fosforos que quer tirar:"))
            while numfosforos!=1 and numfosforos!=2 and numfosforos!=3 and numfosforos!=4 :
                print(" Resposta inválida!")
                numfosforos=int(input(f" Só pode retirar 1,2,3 ou 4 fosforos dos {inicio}. Quantos quer tirar?"))
            inicio=inicio-numfosforos
            print(f" Removi {numfosforos} e sobram {inicio} fosforos.")
        if inicio<=5:
            pc_fosforos=inicio-1
            inicio=inicio-pc_fosforos
            print(f" O computador removeu {pc_fosforos} e sobra {inicio} fosforo.")
            print (" Você perdeu o jogo!")


if mod==2:
    print(" O computador é o primeiro a jogar!")
    pc_fosforos = random.randint(1,4)
    inicio=inicio-pc_fosforos
    print(f" O computador removeu {pc_fosforos} e sobram {inicio} fosforos.")
    numfosforos=int(input(f" Dos {inicio} fosforos em jogo só pode tirar 1,2, 3 ou 4 fósforos, digite o número de fosforos que quer tirar:"))
    while numfosforos!=1 and numfosforos!=2 and numfosforos!=3 and numfosforos!=4 :
        print(" Resposta inválida!")
        numfosforos=int(input(f" Só pode retirar 1,2,3 ou 4 fosforos dos {inicio}. Quantos quer tirar?"))
    if numfosforos==1 or numfosforos==2 or numfosforos==3 or numfosforos==4  :
        inicio=inicio-numfosforos
        print(f" Removi {numfosforos} e sobram {inicio} fosforos.")
        while inicio==6 or inicio==11 or inicio==16:
            pc_fosforos = random.randint(1,4)
            inicio=inicio-pc_fosforos
            print(f" O computador removeu {pc_fosforos} e sobram {inicio} fosforos.")
            numfosforos=int(input(f" Dos {inicio} fosforos em jogo só pode tirar 1,2, 3 ou 4 fósforos, digite o número de fosforos que quer tirar:"))
            while numfosforos!=1 and numfosforos!=2 and numfosforos!=3 and numfosforos!=4 :
                print(" Resposta inválida!")
                numfosforos=int(input(f" Só pode retirar 1,2,3 ou 4 fosforos dos {inicio}. Quantos quer tirar?"))
            inicio=inicio-numfosforos
            print(f" Removi {numfosforos} e sobram {inicio} fosforo(s).")
            if inicio==1:
                print(" O computador perdeu! Parabéns você ganhou!")

        if inicio!=6 and inicio!=11 and inicio!=16 and inicio>1:
            pc_fosforos=0
            while inicio>1:
                while inicio!=6 and inicio!=11 and inicio!=16:
                    pc_fosforos=pc_fosforos+1
                    inicio=inicio-1
                print(f" O computador removeu {pc_fosforos} e sobram {inicio} fosforos.")
                numfosforos=int(input(f" Dos {inicio} fosforos em jogo só pode tirar 1,2, 3 ou 4 fósforos, digite o número de fosforos que quer tirar:"))
                while numfosforos!=1 and numfosforos!=2 and numfosforos!=3 and numfosforos!=4 :
                    print(" Resposta inválida!")
                    numfosforos=int(input(f" Só pode retirar 1,2,3 ou 4 fosforos dos {inicio}. Quantos quer tirar?"))
                inicio=inicio-numfosforos
                print(f" Removi {numfosforos} e sobram {inicio} fosforos.")
                pc_fosforos= 5-numfosforos
                inicio=inicio-pc_fosforos
            if inicio==1:
                print(f" O computador removeu {pc_fosforos} e sobram {inicio} fosforos.")
                print (" Você perdeu o jogo! O computador ganhou!")
