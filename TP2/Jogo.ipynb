# %%
import random

print("Nome do jogo: Adivinha o número")
print("Este jogo tem duas modalidades:")
print("1- O computador pensa num número (entre 0 e 100) e o utilizador tenta adivinhar.")
print("2- O utilizador pensa num número (entre 0 e 100) e o computador tenta adivinhar.")
print("Quem escolheu o número terá de dizer se a resposta está certa, ou se o número é Maior ou Menor.")
modalidade=int(input("Qual a modalidade que pretende jogar? 1 ou 2?:"))

while modalidade!= 1 and modalidade!=2:
    print("Resposta inválida!")
    modalidade=int(input("Qual a modalidade que pretende jogar? 1 ou 2?:"))

if modalidade==1:
    numero = random.randint(0,100)
    palpite=int(input("Introduza o seu palpite:"))
    tentativas= 1
    if palpite==numero:
        print(f"Acertou!! Utilizou apenas 1 tentativa.") 
    while palpite!=numero:
        if palpite<numero:
            print ("O número que pensei é maior.")
            palpite=int(input("Introduza o seu palpite:"))
            tentativas= tentativas + 1
        elif palpite>numero:
            print ("O número que pensei é menor.")
            palpite=int(input("Introduza o seu palpite:"))
            tentativas= tentativas + 1
    print(f"Acertou!! Utilizou {tentativas} tentativa(s).")   

elif modalidade==2:
    print("Vou tentr adivinhar o seu número!")
    menor=0
    maior=100
    num=(maior+menor)/2
    num1=num
    print(f"O seu número é {num}?")
    tentativas=1
    resposta=input("Responda com *Acertou*, com *Maior* se o número for maior ou com *Menor* se o número for menor.")
    if resposta=="Acertou":
       print(f"Acertei!! Utilizei apenas 1 tentativa.") 
    while resposta!="Acertou":
        tentativas=tentativas+1
        if resposta=="Maior":
            menor=num1+1
            num1=(menor+maior)//2
            print(f"O seu número é {num1}?")
            resposta=input("Responda com Acertou ou o número é Maior ou o número é Menor.")
        elif resposta=="Menor":
            maior=num1-1
            num1=(menor+maior)//2
            print(f"O seu número é {num1}?")
            resposta=input("Responda com Acertou ou o número é Maior ou o número é Menor.")
        else:
            print("Resposta inválida")
            resposta=input("Responda com Acertou ou o número é Maior ou o número é Menor.")
    print(f"Acertei!! Utilizei {tentativas} tentativa(s).")
